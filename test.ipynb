# %%
import pandas as pd

# %%
df = pd.read_csv("filtered_output.csv")
df
# Out:
#    SỞ GIÁO DỤC VÀ ĐÀO TẠO BÌNH DƯƠNG  Unnamed: 1        Unnamed: 2 Unnamed: 3  \
# 0                                178       10178     Lê Nguyễn Gia        Hân
# 1                                197       10197        Nguyễn Gia       Hiếu
# 2                                705       10705  Trần Phan Phương         An
#
#   Unnamed: 4  Unnamed: 5       Unnamed: 6              Unnamed: 7  \
# 0         Nữ  03/02/2010  TP. Hồ Chí Minh  Trường THCS Chu Văn An
# 1        Nam  01/01/2010          Phú Thọ    Trường THCS Mỹ Phước
# 2         Nữ  03/01/2010  TP. Hồ Chí Minh    Trường THCS Phú Long
#
#               Unnamed: 8 Unnamed: 9  ... Unnamed: 17             Unnamed: 18  \
# 0  Thành phố Thủ Dầu Một       SINH  ...           1  THPT Chuyên Hùng Vương
# 1      Thành phố Bến Cát         LÍ  ...           1  THPT Chuyên Hùng Vương
# 2     Thành phố Thuận An       TOÁN  ...           2     Trường THCS Phú Hòa
#
#    Unnamed: 19  Unnamed: 20 Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# ...
